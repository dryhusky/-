# %% [markdown]
# <a href="https://colab.research.google.com/github/dryhusky/-/blob/master/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%EC%82%AC%EA%B4%80%ED%95%99%EA%B5%90_%ED%94%84%EB%A6%AC%EC%BD%94%EC%8A%A4_%EA%B3%BC%EC%A0%9C_1%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### <언어>
#
# 1. AI자기소개서 검사기
#   * 자소서의 단어들을 분석하여 개인의 성향을 판단하고, 기업에서 필요한 인재를 분별하는데 도움을 준다.
#   * 자소서에 작성된 단어들을 토대로 본인의 성향을 파악할 수 있으며,그래프로 강점이 무엇인지도 판단할 수 있다.
#
#
# 2. 구글번역
#   * 2007년 구글에서 발표한 무료 번역 서비스로, 현재 세계에서 가장 많이 사용되는 기계번역 서비스이다
#   * 과거 발번역한것에 대해 구글번역기 돌렸냐는 말이 있었는데, 2016년부터 알파고에 쓰인 딥러닝을 적용하고, 추후 인공신경망을 적용하는 등 발전 과정을 거쳐 지금은 상당히 자연스러운 번역기능을 지원해준다.
#
#
# 3. AI 글쓰기(오픈AI)
#  * 비영리 인공지능 연구기관인 오픈AI으로 자동 문장생성 인공지능 모델(GPT-2)을
#   공개하였다.
#  * GPT-2는 15억개 파라미터를 가진 대규모 번역기반 언어모델로, 800만개 텍스트의
#    데이터셋을 통해 학습했다. 임의의 문장을 입력하면 맥락을 고려한 종합적인
#   문장을 스스로 만들어낸다
#
#
# 4. 강남구 주정차 민원 상담봇
#  * 채팅로봇(챗봇)은 24시간 365일 응대 가능한 대화형 상담 시스템이다.
#  * 사용자의 의도를 파악하기 위한 자동 질의도 하며, 민원을 처리할 수 있다.
#
#
# #### <음성>
#
# 1. 바이두의 음성녹음
#  * 인공지능과 딥 러닝 기술을 적용한 음성 모방 솔루션 딥 보이스 (Deep Voice)는
#    3.7초의 음성 데이터만 있으면 음성을 복제하는 데 가능하다.
#  * 별도의 녹음 없이 자동화하여 책을 읽어주는 기술도 개발이 되어있다.
#
#
# 2. 애플의 시리
#   * 애플은 AI를 이용하여 애플 뮤직에서 노래를 추천하거나, 아이클라우드에서
#   사진을 찾거나, 지도를 사용하여 다음 목적지로 이동할 수 이도록 도와주는 등 다양한 서비스를 사용자에게 제공하고 있다.
#
#
# 3. 음성녹음을 텍스트변환
#  * 음성으로 말한 것을 AI가 언어로 써준다.
#    글을 작성하는데 편리함을 주며, 정확하진 않더라도 어느정도 의미를 파악할 수
#    있기에 학생이 수업을 들을 때 활용하곤 한다.
#
#
# 4. 스웨덴 SEB은행의 Amelia
#  * 내부 고객 및 은행 상담에 인공지능 비서를 활용하여 이용자에게 편의성과
#    인건비를 절약 하고 있다.
#
#
# #### <이미지>
#
# 1. 파파고
#  * 외국어를 파파고로 촬영하게 되면, 사용자가 원하는 언어로 번역시켜주는 작업을
#    해준다.
#
#
# 2. 구글 헬스 AI
#  * 구글 헬스의 스콧 마이어 매키니 연구원 연구팀은 “AI가 유방암 조기 진단
#    정확도에서 방사선 전문의를 능가했다”는 연구결과를 네이처에 발표하였다.
#  * 최근에는 빅데이터의 방대한 자료로 학습한 AI로 치료 후 경과를 예측하는
#   부분에서도 탁월한 성과를 보여주었다.
#
#
# 3. 쉴드의 AI
#  * 쉴드는 미 국가안보국에 인공지능(AI)을 납품하고 있는 회사이다.
#  * 스스로 위험물(폭발물, 무기 등등)을 찾아내거나 적군을 식별하는 등
#    사람이 가기 힘든 장소를 정찰하는 역활을 하고 있다.
#
#
# 4. 지형 공간 데이터를 분석하는 AI
#  * IBM의 인공지능 중 하나는 다중위성으로 수집한 정보를 토대로 지형공간을
#    분석하여 스마트 팜을 운영하는데 적절한 정보를 제공해준다.
#
#
# #### <자율주행>
#
# 1. 테슬라
#  * 몇몇 사람들은 테슬라하면 가장 먼저 떠오르는게 자율주행일 것이다. 현재 2020년 말까지 LV5을 목표로 개발중에 있으며, 여기서 LV5는 되면 완전 자율주행, 즉 감시자(운전자)가 운전에 신경쓰지 않아도 목표지점까지 안전하게 주행이 되는 수준이다.
#  * 2020년 2월까지 테슬라가 축적한 오토 파일럿의 도로주행 데이터는  48억km로 엄청 방대한 수준이며, 이것이 있었기에 오토 파일럿 주행의 학습이 가능했다.
#
#
# 2. 현대차와 기아차의 SCC-ML
#  * 기존에 있던 스마트 크루즈 컨트롤은 앞차와의 간격을 안정한 간격만큼 거리를 유지해 주행해주는 시스템이였었다.
#  *19년에 개발된 SCC-ML은 운전자의 주행성향에 맞는 부분을 AI로 학습하여 자율주행으로 구현하는 SCC-ML을 개발하였다.
#
#
# 3.  BMW와 앤시스(ANSYS)의 자율주행 시뮬레이션  툴 개발
#  * 자율주행이 발전하고 보급됨에 따라 운전자의 안정성에 대한 우려가 커져가고 있다. 그래서 이를 실제 주행이 아닌, 자율주행을 시뮬레이션 할 수 있는 툴을  협력하여 만들고 있다.
#
#
# 4. 에어택시
#  * 우버콥터는 차로 50분의 거리를 8분만에 돌파할 수 있는 속도를 가지고 있다.
#  * 많은 기업이 투자를 하고 있는데, 이런 에어택시를 2019년에 "오로라플라이드
#    사이언스" 기업이 자율주행에 성공하였고, 보잉에 인수되었다.
